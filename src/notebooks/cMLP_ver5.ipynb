# %%
import os, sys, math, time
import numpy as np
import numpy.linalg as la
import plotly.graph_objects as go
import plotly.express as ex
from plotly.subplots import make_subplots
import pandas as pd

import json as js
import _pickle as pickle
import bz2
import ray

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torch.utils.data import Dataset, TensorDataset
from torch.utils.data import DataLoader
from torch.utils.data.dataset import random_split
from collections import OrderedDict

from ray import tune
from ray.tune.suggest.bayesopt import BayesOptSearch
import shutil
import tempfile
from ray.tune import CLIReporter, JupyterNotebookReporter
from ray.tune.schedulers import ASHAScheduler, PopulationBasedTraining
from ray.tune.integration.pytorch_lightning import TuneReportCallback, \
    TuneReportCheckpointCallback

import pytorch_lightning as pl
from pytorch_lightning.utilities.cloud_io import load as pl_load
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning.callbacks import EarlyStopping

from cytoolz import sliding_window
sys.path.append("../")
import func

# %%
ray.shutdown()
# Prepare train data
DATA_PATH = "/home/nuoc/Documents/MEX/data"
MODEL_PATH = "/home/nuoc/Documents/MEX/models"
RESULTS_PATH = "/home/nuoc/Documents/MEX/results"

# %%
# Test torch lightning + ray tune

class MLP(pl.LightningModule):
    def __init__(self, config:dict=None, dimensions:list=None,
                 train_set=None, val_set=None, test_set=None,
                 keep_prob:float=.2, name:str="model", load=False,
                 single_module:int=0):

        super(MLP, self).__init__()
        self.name = name
        self.dimensions = dimensions
        self.keep_prob = keep_prob
        self.single_module = single_module

        if load:
            self.build()
        else:
            self.k = config["k"]
            self.learning_rate = config["lr"]
            self.loss_fn = config["ae_loss_fn"]
            self.batch_size = config["batch_size"]

            dimensions.append(self.k)
            self.dimensions = dimensions
            self.train_set = train_set
            self.val_set = val_set
            self.test_set = test_set

            self.best_val_loss = np.inf

        self.build()
        self.encoder.apply(self.init_params)
        self.decoder.apply(self.init_params)

    def build(self):
        layer_sizes = list(sliding_window(2, self.dimensions))
        if self.single_module == -1 or self.single_module == 0:
            layers = []

            for i, size in enumerate(layer_sizes):
                layers.append(("fc"+str(i), nn.Linear(size[0], size[1])))
                if i < len(self.dimensions)-2:
                    layers.append(("act"+str(i), nn.ELU()))
                    layers.append(("drop"+str(i+1), nn.Dropout(self.keep_prob)))
            self.encoder = nn.Sequential(OrderedDict(layers))
        else:
            self.encoder = nn.Sequential()

        if self.single_module == 0 or self.single_module == 1:
            layers = []
            for i, size in enumerate(layer_sizes[-1::-1]):
                layers.append(("fc"+str(i), nn.Linear(size[1], size[0])))
                if i < len(self.dimensions)-2:
                    layers.append(("act"+str(i), nn.ELU()))
                    layers.append(("drop"+str(i+1), nn.Dropout(self.keep_prob)))
            self.decoder = nn.Sequential(OrderedDict(layers))
        else:
            self.decoder = nn.Sequential()

    def forward(self, x:torch.Tensor) -> torch.Tensor:
        return self.decoder(self.encoder(x))

    def training_step(self, batch, batch_idx):
        x, y = batch
        prediction = self(x)
        loss = self.loss_fn(prediction, y)

        self.log("ptl/train_loss", loss)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch

        prediction = self(x)
        loss = self.loss_fn(prediction, y)

        self.log('ptl/val_loss', loss, prog_bar=True)
        return {"val_loss":loss}

    def test_step(self, batch, batch_idx):
        x, y = batch

        prediction = self(x)
        loss = self.loss_fn(prediction, y)

        self.log('ptl/test_loss', loss, prog_bar=True)
        return {"val_loss":loss}

    def validation_epoch_end(self, outputs):
        avg_loss = torch.stack([x["val_loss"] for x in outputs]).mean()
        self.log("avg_val_loss", avg_loss)
        if avg_loss < self.best_val_loss:
            self.best_val_loss = avg_loss
            self.save_checkpoint()

    def save_checkpoint(self, checkpoint_dir=MODEL_PATH):
        model = {"k":self.k, "dimensions":self.dimensions,"keep_prob":self.keep_prob, "name":self.name,
                 "encoder":self.encoder.state_dict(),
                 "decoder":self.decoder.state_dict()}


        if not os.path.exists(checkpoint_dir):
            os.mkdir(checkpoint_dir)
        path = os.path.join(checkpoint_dir, self.name)
        if not os.path.exists(path):
            os.mkdir(path)

        filePath = os.path.join(path, "."+str(self.k)+".pbz2")
        with bz2.BZ2File(filePath, "w") as f:
            pickle.dump(model, f)
        return filePath
    def load(self, state_dict1: 'OrderedDict[str, Tensor]'=None, state_dict2: 'OrderedDict[str, Tensor]'=None,
                        strict: bool = True):

        if self.single_module == -1 or self.single_module == 0:
            self.encoder.load_state_dict(state_dict1, strict)
        if self.single_module == 1 or self.single_module == 0:
            self.decoder.load_state_dict(state_dict2, strict)
    @staticmethod
    def load_checkpoint(filePath):
        with bz2.BZ2File(filePath, "rb") as f:
            obj = pickle.load(f)
        model = MLP(name=obj["name"], dimensions=obj["dimensions"], load=True)
        model.encoder.load_state_dict(obj["encoder"])
        model.decoder.load_state_dict(obj["decoder"])
        return model

    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(self.parameters(), lr=self.learning_rate)
        return optimizer

    def setup_data(self):
        pass
    def train_dataloader(self):
        return DataLoader(self.train_set, batch_size=self.batch_size, pin_memory=True)

    def val_dataloader(self):
        return DataLoader(self.val_set, batch_size=self.batch_size, pin_memory=True)

    def test_dataloader(self):
        return DataLoader(self.test_set, batch_size=self.batch_size, pin_memory=True)

    @staticmethod
    def init_params(m):
        if type(m) == nn.Linear:
            nn.init.xavier_uniform_(m.weight)
            m.bias.data.fill_(.01)

# %%
class MIX(pl.LightningModule):
    def __init__(self, config:dict=None, dim1:int=None, dim2:int=None, dim3:int=None, dim4:int=None,
                 train_set=None, val_set=None, test_set=None,
                 name:str="model"):

        super(MIX, self).__init__()
        self.name = name
        if not config is None:
            self.k = config["k"]
            self.hidden_dim = config["hidden_dim"]
            self.learning_rate = config["lr"]
            self.loss_fn = config["loss_fn"]
            self.batch_size = config["batch_size"]

        self.dim1 = dim1
        self.dim2 = dim2
        self.dim3 = dim3
        self.dim4 = dim4
        self.dimension1 = [dim1 , self.hidden_dim , self.k]
        self.dimension2 = [dim2 , self.hidden_dim , self.k]
        self.dimension3 = [dim3 , self.hidden_dim , self.k]
        self.dimension4 = [dim4 , self.hidden_dim , self.k]

        self.model1 = MLP(config=config, dimensions=self.dimension1, name="M1")
        self.model2 = MLP(config=config, dimensions=self.dimension2, name="M2")
        self.model3 = MLP(config=config, dimensions=self.dimension3, name="M3")
        self.model4 = MLP(config=config, dimensions=self.dimension4, name="M4")

        self.train_set = train_set
        self.val_set = val_set
        self.test_set = test_set
        self.best_val_loss = np.inf

    def forward(self, x:torch.Tensor) -> (torch.Tensor,torch.Tensor,torch.Tensor,torch.Tensor):
        i1 = self.dim1
        i2 = i1+self.dim2
        i3 = i2+self.dim3
        input1, input2, input3, input4 = \
            x[:, :i1], x[:, i1:i2], x[:, i2:i3], x[:, i3:]
        h1, h2, h3, h4 = \
            self.model1.encoder(input1), self.model2.encoder(input2), self.model3.encoder(input3), self.model4.encoder(input4)

        out1, out2, out3, out4 = \
            self.model1.decoder(h1), self.model2.decoder(h2), self.model3.decoder(h3), self.model4.decoder(h4)
        return (out1, out2, out3, out4), (h1, h2, h3, h4)

    def training_step(self, batch, batch_idx):
        x, y = batch
        out, h = self(x)
        loss = self.loss_fn(out, h, y)

        self.log("ptl/train_loss", loss)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch

        out, h = self(x)
        loss = self.loss_fn(out, h, y)


        self.log('ptl/val_loss', loss, prog_bar=True)
        return {"val_loss":loss}

    def test_step(self, batch, batch_idx):
        x, y = batch

        out, h = self(x)
        loss = self.loss_fn(out, h, y)


        self.log('ptl/test_loss', loss, prog_bar=True)
        return {"val_loss":loss}

    def validation_epoch_end(self, outputs):
        avg_loss = torch.stack([x["val_loss"] for x in outputs]).mean()
        self.log("avg_val_loss", avg_loss)
        if avg_loss < self.best_val_loss:
            self.best_val_loss = avg_loss
            self.save_checkpoint()

    def save_checkpoint(self, checkpoint_dir=MODEL_PATH):
        path = os.path.join(checkpoint_dir, self.name)
        model_path1 = self.model1.save_checkpoint(checkpoint_dir=MODEL_PATH)
        model_path2 = self.model2.save_checkpoint(checkpoint_dir=MODEL_PATH)
        model_path3 = self.model3.save_checkpoint(checkpoint_dir=MODEL_PATH)
        model_path4 = self.model4.save_checkpoint(checkpoint_dir=MODEL_PATH)


        model = {"name":self.name,
                 "model1_name":self.model1.name,
                 "k": self.k,
                 "model1_single_module":self.model1.single_module, "model1_path" : model_path1,
                 "model2_name":self.model2.name,
                 "model2_single_module":self.model2.single_module, "model2_path" : model_path2,
                 "model3_name":self.model3.name,
                 "model3_single_module":self.model3.single_module, "model3_path" : model_path3,
                 "model4_name":self.model4.name,
                 "model4_single_module":self.model4.single_module, "model4_path" : model_path4,
                 }
        if not os.path.exists(path):
            os.mkdir(path)
        with bz2.BZ2File(os.path.join(path,
                                      str(self.best_val_loss.cpu().numpy())+"."+str(self.k)+".pbz2"), "w") as f:
            pickle.dump(model, f)

    @staticmethod
    def load_checkpoint(filename):
        # return torch.load(os.path.join(checkpoint_dir,filename))
        with bz2.BZ2File(filename, "rb") as f:
            obj = pickle.load(f)

        model1 = MLP.load_checkpoint(obj["model1_path"])
        model2 = MLP.load_checkpoint(obj["model2_path"])
        model3 = MLP.load_checkpoint(obj["model3_path"])
        model4 = MLP.load_checkpoint(obj["model4_path"])

        model = MIX(name=obj["name"])
        model.model1 = model1
        model.model2 = model2
        model.model3 = model3
        model.model4 = model4

        return model
        # self.encoder.load_state_dict(obj["encoder"])
        # self.decoder.load_state_dict(obj["decoder"])
        # self.best_val_loss = obj["val_loss"]

    def setup_data(self): pass
    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(self.parameters(), lr=self.learning_rate)
        return optimizer

    def train_dataloader(self):
        return DataLoader(self.train_set, batch_size=self.batch_size, pin_memory=True)

    def val_dataloader(self):
        return DataLoader(self.val_set, batch_size=self.batch_size, pin_memory=True)

    def test_dataloader(self):
        return DataLoader(self.test_set, batch_size=self.batch_size, pin_memory=True)

# %%
def train_tune(config, dim1, dim2, dim3,dim4,
                 train_set=None, val_set=None, test_set=None,
                 num_epochs=300, num_cpus=24, num_gpus=1, model_name="model"):

    model = MIX(config=config, dim1=dim1, dim2=dim2, dim3=dim3, dim4=dim4,
                train_set=train_set, val_set=val_set, test_set=test_set, name=model_name)
    trainer = pl.Trainer(
        max_epochs=num_epochs,
        gpus=num_gpus,
        logger=TensorBoardLogger(save_dir="logs/", name=model_name, version="0.0"),
        progress_bar_refresh_rate=20,
        callbacks=[
            TuneReportCallback({"loss":"avg_val_loss",}, on="validation_end"),
            EarlyStopping(monitor="avg_val_loss")
        ],
        precision=16,
    )
    trainer.fit(model)

# %%
def prepare_data(datasets:list, featureList:list,
                 train_ratio:float=0.8, val_ratio:float=0.2, test_size:int=100, SEED:int=2021):
   # process data
    data = [func.processData(d, featureList, shutdown=False) for d in datasets]
    input_data = [np.vstack(d) for d in data]
    x_tensors = [func.normaliseT(torch.from_numpy(x).float()) for x in input_data]
    y_tensors = [torch.from_numpy(x).float() for x in input_data]

    # prepare datasets
    test_sets = [(x_tensor[-test_size:], y_tensor[-test_size:]) for x_tensor, y_tensor in zip(x_tensors, y_tensors)]
    x_training = torch.vstack([x_tensor[:-test_size] for x_tensor in x_tensors])
    y_training = torch.vstack([y_tensor[:-test_size] for y_tensor in y_tensors])
    dataset = TensorDataset(x_training, y_training)
    N = len(x_training)

    train_ratio = int(train_ratio*N)
    val_ratio = int(val_ratio*N)
    print("Train: ", train_ratio, ", Validation: ", val_ratio)
    train_set, val_set = random_split(dataset, [train_ratio, val_ratio], generator=torch.Generator().manual_seed(SEED))
    return train_set, val_set, test_sets

def train(train_set:Dataset, val_set:Dataset, dims:list,
          config:dict, EPOCHS:int=300,
          n_gpu=1, n_samples=20, model_name="model",
          ):

    dim1, dim2, dim3, dim4 = dims[0], dims[1], dims[2],dims[3]

    scheduler = ASHAScheduler(max_t = EPOCHS, grace_period=1, reduction_factor=2)
    reporter = CLIReporter(
        parameter_columns=["k", "lr", "batch_size"],
        metric_columns=["loss", "training_iteration"],
        max_error_rows=5,
        max_progress_rows=5,
        max_report_frequency=10)
    analysis = tune.run(
        tune.with_parameters(
            train_tune,
            dim1=dim1, dim2=dim2, dim3=dim3, dim4=dim4,
            train_set = train_set, val_set = val_set,
            num_epochs = EPOCHS,
            num_gpus=n_gpu,
            model_name=model_name
        ),
        resources_per_trial= {"cpu":1, "gpu":n_gpu},
        metric="loss",
        mode="min",
        config=config,
        num_samples=n_samples,
        scheduler=scheduler,
        progress_reporter=reporter,
        name=model_name,
        verbose=False,
        checkpoint_freq=0,
        keep_checkpoints_num=1,
        checkpoint_score_attr="loss",
        checkpoint_at_end=True
    )

    print("-"*70)
    print("Done")
    print("Best hyperparameters found were: ", analysis.best_config)
    print("Best achieved loss was: ", analysis.best_result)
    print("-"*70)

def clean_checkpoints(num_keep=3, path="../../models"):
    for dir, dname, files in os.walk(path):
        saved_checkpoints = []
        for fname in files:
            fname = fname.split(".")
            saved_checkpoints.append(fname)
        print("Num checkpoints in {}: {}".format(dir, len(saved_checkpoints)))

        saved_checkpoints.sort(key = lambda x: x[1])
        for filename in saved_checkpoints[num_keep:]:
            os.remove(os.path.join(dir,".".join(filename)))

def test(model:torch.nn.Module, test_sets:list, loss_fn, set_names=list,
         save=True, path="../../results", model_name="model"):
    # Intra test performance
    with torch.no_grad():
        df = {}
        if set_names is None: set_names = np.arange(len(test_sets))
        for i,t1 in enumerate(test_sets):
            for j, t2 in enumerate(test_sets):
                x = t1[0]
                y = t2[1]
                out1, out2, h1, h2 = model(x)
                loss = loss_fn(out1, out2, h1, h2, y)
                df["{}-{}".format(set_names[i], set_names[j])] = [loss.cpu().numpy()]
                print("Test encoding {} to {}, MSE={:.2f}".format(set_names[i], set_names[j], loss))
        filepath = os.path.join(path, model_name)
        if not os.path.exists(filepath): os.mkdir(filepath)
        pd.DataFrame(df).to_csv(os.path.join(filepath, "tests.csv"))

def test2(model:torch.nn.Module, test_sets:list, loss_fn, set_names=list,
         save=True, path="../../results", model_name="model"):
    # Intra test performance
    with torch.no_grad():
        df = {}
        if set_names is None: set_names = np.arange(len(test_sets))
        for i,t1 in enumerate(test_sets):
            x = t1[0]
            y = t1[1]
            out, h = model(x)
            loss = loss_fn(out, h, y)
            df["{}".format(set_names[i])] = [loss.cpu().numpy()]
            print("Test encod>ing {} = {:.2f}".format(set_names[i], loss))
        filepath = os.path.join(path, model_name)
        if not os.path.exists(filepath): os.mkdir(filepath)
        pd.DataFrame(df).to_csv(os.path.join(filepath, "tests.csv"))

# %%
def train_multi_model(datapaths:list, featureList:list, config:dict=None,
                       n_samples:int=30, model_name:str="model", loss_fn=nn.functional.mse_loss,
                       dataset_names:list=None):
    # load data
    datasets1 = [func.load(os.path.join(DATA_PATH,path)) for path in datapaths[0]]
    datasets2 = [func.load(os.path.join(DATA_PATH,path)) for path in datapaths[1]]
    datasets3 = [func.load(os.path.join(DATA_PATH,path)) for path in datapaths[2]]
    datasets4 = [func.load(os.path.join(DATA_PATH,path)) for path in datapaths[3]]

    train_set1, val_set1, test_set1 = prepare_data(datasets1, featureList)
    train_set2, val_set2, test_set2 = prepare_data(datasets2, featureList)
    train_set3, val_set3, test_set3 = prepare_data(datasets3, featureList)
    train_set4, val_set4, test_set4 = prepare_data(datasets4, featureList)

    dims = [len(train_set1[0][0]),len(train_set2[0][0]),len(train_set3[0][0]),len(train_set4[0][0])]
    train_set = [(torch.cat([x[0],y[0],z[0],w[0]],dim=0),torch.cat([x[1],y[1],z[1],w[1]],dim=0))
                 for x, y, z, w in zip(train_set1, train_set2, train_set3, train_set4)]
    val_set = [(torch.cat([x[0],y[0],z[0],w[0]],dim=0),torch.cat([x[1],y[1],z[1],w[1]],dim=0))
                 for x, y, z, w in zip(val_set1, val_set2, val_set3, val_set4)]
    train(train_set=train_set, val_set=val_set, config=config, dims=dims,
          n_samples=n_samples, model_name=model_name)


    # test_set = [(torch.cat([x[0],y[0],z[0],w[0]],dim=0),torch.cat([x[1],y[1],z[1],w[1]],dim=0))
                 # for x, y, z, w in zip(test_set1, test_set2, test_set3, test_set4)]
    # clean_checkpoints(path=MODEL_PATH)
    # best_model = MIX.load_checkpoint(best_model)
    return [test_set1, test_set2, test_set3, test_set4]
    # test2(best_model, test_set, loss_fn=loss_fn, set_names=dataset_names, path=RESULTS_PATH)

# %%
def mse_loss(out, h, y):
    return nn.functional.mse_loss(torch.cat((out[0], out[1], out[2], out[3]), dim=1), y)

def mse_mse_loss(out, h, y):
    i1 = out[0].size()[-1]
    i2 = i1 + out[1].size()[-1]
    i3 = i2 + out[2].size()[-1]
    y0, y1, y2, y3 = y[:, :i1], y[:, i1:i2],y[:, i2:i3], y[:, i3:]

    mse0 = nn.functional.mse_loss(out[0], y0)
    mse1 = nn.functional.mse_loss(out[1], y1)
    mse2 = nn.functional.mse_loss(out[2], y2)
    mse3 = nn.functional.mse_loss(out[3], y3)

    s_loss0 = nn.functional.mse_loss(h[0], h[1])
    s_loss1 = nn.functional.mse_loss(h[0], h[2])
    s_loss2 = nn.functional.mse_loss(h[0], h[3])
    s_loss3 = nn.functional.mse_loss(h[1], h[2])
    s_loss4 = nn.functional.mse_loss(h[1], h[3])
    s_loss5 = nn.functional.mse_loss(h[2], h[3])

    mse = (mse0 + mse1 + mse2 + mse3) / 4
    similarity_loss = (s_loss0 + s_loss1 + s_loss2 + s_loss3 + s_loss4 + s_loss5) / 6
    return (mse + similarity_loss) / 2.0

def mse_mae_loss(out, h, y):
    i1 = out[0].size()[-1]
    i2 = i1 + out[1].size()[-1]
    i3 = i2 + out[2].size()[-1]
    y0, y1, y2, y3 = y[:, :i1], y[:, i1:i2],y[:, i2:i3], y[:, i3:]

    mse0 = nn.functional.mse_loss(out[0], y0)
    mse1 = nn.functional.mse_loss(out[1], y1)
    mse2 = nn.functional.mse_loss(out[2], y2)
    mse3 = nn.functional.mse_loss(out[3], y3)

    s_loss0 = nn.functional.smooth_l1_loss(h[0], h[1])
    s_loss1 = nn.functional.smooth_l1_loss(h[0], h[2])
    s_loss2 = nn.functional.smooth_l1_loss(h[0], h[3])
    s_loss3 = nn.functional.smooth_l1_loss(h[1], h[2])
    s_loss4 = nn.functional.smooth_l1_loss(h[1], h[3])
    s_loss5 = nn.functional.smooth_l1_loss(h[2], h[3])

    mse = (mse0 + mse1 + mse2 + mse3) / 4
    similarity_loss = (s_loss0 + s_loss1 + s_loss2 + s_loss3 + s_loss4 + s_loss5) / 6
    return (mse + similarity_loss) / 2.0

def mse_kl_loss(out, h, y):
    i1 = out[0].size()[-1]
    i2 = i1 + out[1].size()[-1]
    i3 = i2 + out[2].size()[-1]
    y0, y1, y2, y3 = y[:, :i1], y[:, i1:i2],y[:, i2:i3], y[:, i3:]

    mse0 = nn.functional.mse_loss(out[0], y0)
    mse1 = nn.functional.mse_loss(out[1], y1)
    mse2 = nn.functional.mse_loss(out[2], y2)
    mse3 = nn.functional.mse_loss(out[3], y3)

    s_loss0 = nn.functional.kl_div(h[0], h[1])
    s_loss1 = nn.functional.kl_div(h[0], h[2])
    s_loss2 = nn.functional.kl_div(h[0], h[3])
    s_loss3 = nn.functional.kl_div(h[1], h[2])
    s_loss4 = nn.functional.kl_div(h[1], h[3])
    s_loss5 = nn.functional.kl_div(h[2], h[3])

    mse = (mse0 + mse1 + mse2 + mse3) / 4
    similarity_loss = (s_loss0 + s_loss1 + s_loss2 + s_loss3 + s_loss4 + s_loss5) / 6
    return (mse + similarity_loss) / 2.0

def mse_nll_loss(out, h, y):
    i1 = out[0].size()[-1]
    i2 = i1 + out[1].size()[-1]
    i3 = i2 + out[2].size()[-1]
    y0, y1, y2, y3 = y[:, :i1], y[:, i1:i2],y[:, i2:i3], y[:, i3:]

    mse0 = nn.functional.mse_loss(out[0], y0)
    mse1 = nn.functional.mse_loss(out[1], y1)
    mse2 = nn.functional.mse_loss(out[2], y2)
    mse3 = nn.functional.mse_loss(out[3], y3)

    s_loss0 = nn.functional.nll_loss(h[0], h[1])
    s_loss1 = nn.functional.nll_loss(h[0], h[2])
    s_loss2 = nn.functional.nll_loss(h[0], h[3])
    s_loss3 = nn.functional.nll_loss(h[1], h[2])
    s_loss4 = nn.functional.nll_loss(h[1], h[3])
    s_loss5 = nn.functional.nll_loss(h[2], h[3])

    mse = (mse0 + mse1 + mse2 + mse3) / 4
    similarity_loss = (s_loss0 + s_loss1 + s_loss2 + s_loss3 + s_loss4 + s_loss5) / 6
    return (mse + similarity_loss) / 2.0

# %%
datapath1 = ["LOCO_R1-default-locomotion.pbz2",
             "LOCO_R1-default-locomotion-small.pbz2",
             "LOCO_R1-default-locomotion-large.pbz2"]
datapath2 = ["LOCO_R2-default-locomotion.pbz2",
             "LOCO_R2-default-locomotion-small.pbz2",
             "LOCO_R2-default-locomotion-large.pbz2"]
datapath3 = ["LOCO_R3-default-locomotion.pbz2",
             "LOCO_R3-default-locomotion-small.pbz2",
             "LOCO_R3-default-locomotion-large.pbz2"]
datapath4 = ["LOCO_R4-default-locomotion.pbz2",
             "LOCO_R4-default-locomotion-small.pbz2",
             "LOCO_R4-default-locomotion-large.pbz2"]
featureList = ["pos", "rotMat", "velocity"]

# %%
config = {
    "k": tune.randint(6, 256),
    "hidden_dim" : tune.choice([64, 128, 256]),
    "lr": tune.loguniform(1e-2, 1e-7),
    "batch_size":tune.choice([5, 15, 30, 60]),
    "loss_fn":tune.choice([mse_mse_loss, mse_mae_loss, mse_kl_loss, mse_nll_loss]),
    "ae_loss_fn":tune.choice([mse_loss])
}

train_multi_model([datapath1,datapath2,datapath3,datapath4], featureList, config,
                       n_samples=30, model_name="MIX4", loss_fn=mse_loss,
                       dataset_names=["R1","R2","R3","R4"])
# Out:
# 2021-04-01 00:12:42,028	INFO services.py:1172 -- View the Ray dashboard at http://127.0.0.1:8265
# 2021-04-01 00:12:42,610	INFO worker.py:664 -- Calling ray.init() again after it has already been called.
# 2021-04-01 00:12:42,759	INFO worker.py:664 -- Calling ray.init() again after it has already been called.
# 2021-04-01 00:12:42,911	INFO worker.py:664 -- Calling ray.init() again after it has already been called.
# 2021-04-01 00:12:43,060	INFO worker.py:664 -- Calling ray.init() again after it has already been called.
# 2021-04-01 00:12:43,213	INFO worker.py:664 -- Calling ray.init() again after it has already been called.
# 2021-04-01 00:12:43,342	INFO worker.py:664 -- Calling ray.init() again after it has already been called.
# 2021-04-01 00:12:43,586	INFO worker.py:664 -- Calling ray.init() again after it has already been called.
# 2021-04-01 00:12:43,807	INFO worker.py:664 -- Calling ray.init() again after it has already been called.
# 2021-04-01 00:12:44,023	INFO worker.py:664 -- Calling ray.init() again after it has already been called.
# 2021-04-01 00:12:44,219	INFO worker.py:664 -- Calling ray.init() again after it has already been called.
# 2021-04-01 00:12:44,417	INFO worker.py:664 -- Calling ray.init() again after it has already been called.
# 2021-04-01 00:12:45,062	WARNING function_runner.py:540 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# (pid=901164) GPU available: True, used: True
# (pid=901164) TPU available: None, using: 0 TPU cores
# (pid=901164) Using native 16bit precision.
# (pid=901164) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901164)
# (pid=901164)   | Name   | Type | Params
# (pid=901164) --------------------------------
# (pid=901164) 0 | model1 | MLP  | 141 K
# (pid=901164) 1 | model2 | MLP  | 141 K
# (pid=901164) 2 | model3 | MLP  | 160 K
# (pid=901164) 3 | model4 | MLP  | 160 K
# (pid=901164) --------------------------------
# (pid=901164) 604 K     Trainable params
# (pid=901164) 0         Non-trainable params
# (pid=901164) 604 K     Total params
# (pid=901164) 2.418     Total estimated model params size (MB)
# (pid=901164) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901164)   warnings.warn(*args, **kwargs)
# (pid=901164) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901164)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:16:15,688	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_similarity_loss at 0x7f62addae310>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901188) GPU available: True, used: True
# (pid=901188) TPU available: None, using: 0 TPU cores
# (pid=901188) Using native 16bit precision.
# (pid=901188) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901188)
# (pid=901188)   | Name   | Type | Params
# (pid=901188) --------------------------------
# (pid=901188) 0 | model1 | MLP  | 87.9 K
# (pid=901188) 1 | model2 | MLP  | 87.9 K
# (pid=901188) 2 | model3 | MLP  | 126 K
# (pid=901188) 3 | model4 | MLP  | 126 K
# (pid=901188) --------------------------------
# (pid=901188) 428 K     Trainable params
# (pid=901188) 0         Non-trainable params
# (pid=901188) 428 K     Total params
# (pid=901188) 1.714     Total estimated model params size (MB)
# (pid=901188) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901188)   warnings.warn(*args, **kwargs)
# (pid=901188) /home/nuoc/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:2610: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
# (pid=901188)   warnings.warn(
# (pid=901188) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901188)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:16:23,804	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_kl_loss at 0x7f62addae430>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901173) GPU available: True, used: True
# (pid=901173) TPU available: None, using: 0 TPU cores
# (pid=901173) Using native 16bit precision.
# (pid=901173) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901173)
# (pid=901173)   | Name   | Type | Params
# (pid=901173) --------------------------------
# (pid=901173) 0 | model1 | MLP  | 166 K
# (pid=901173) 1 | model2 | MLP  | 166 K
# (pid=901173) 2 | model3 | MLP  | 243 K
# (pid=901173) 3 | model4 | MLP  | 243 K
# (pid=901173) --------------------------------
# (pid=901173) 819 K     Trainable params
# (pid=901173) 0         Non-trainable params
# (pid=901173) 819 K     Total params
# (pid=901173) 3.277     Total estimated model params size (MB)
# (pid=901173) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901173)   warnings.warn(*args, **kwargs)
# (pid=901173) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901173)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:19:02,337	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_mae_loss at 0x7f62addae3a0>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901172) GPU available: True, used: True
# (pid=901172) TPU available: None, using: 0 TPU cores
# (pid=901172) Using native 16bit precision.
# (pid=901172) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901172)
# (pid=901172)   | Name   | Type | Params
# (pid=901172) --------------------------------
# (pid=901172) 0 | model1 | MLP  | 181 K
# (pid=901172) 1 | model2 | MLP  | 181 K
# (pid=901172) 2 | model3 | MLP  | 258 K
# (pid=901172) 3 | model4 | MLP  | 258 K
# (pid=901172) --------------------------------
# (pid=901172) 881 K     Trainable params
# (pid=901172) 0         Non-trainable params
# (pid=901172) 881 K     Total params
# (pid=901172) 3.526     Total estimated model params size (MB)
# (pid=901172) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901172)   warnings.warn(*args, **kwargs)
# (pid=901172) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901172)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:19:07,032	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_similarity_loss at 0x7f62addae310>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901183) GPU available: True, used: True
# (pid=901183) TPU available: None, using: 0 TPU cores
# (pid=901183) Using native 16bit precision.
# (pid=901183) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901183)
# (pid=901183)   | Name   | Type | Params
# (pid=901183) --------------------------------
# (pid=901183) 0 | model1 | MLP  | 245 K
# (pid=901183) 1 | model2 | MLP  | 245 K
# (pid=901183) 2 | model3 | MLP  | 322 K
# (pid=901183) 3 | model4 | MLP  | 322 K
# (pid=901183) --------------------------------
# (pid=901183) 1.1 M     Trainable params
# (pid=901183) 0         Non-trainable params
# (pid=901183) 1.1 M     Total params
# (pid=901183) 4.549     Total estimated model params size (MB)
# (pid=901183) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901183)   warnings.warn(*args, **kwargs)
# (pid=901183) /home/nuoc/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:2610: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
# (pid=901183)   warnings.warn(
# (pid=901183) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901183)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:19:18,373	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_kl_loss at 0x7f62addae430>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901179) GPU available: True, used: True
# (pid=901179) TPU available: None, using: 0 TPU cores
# (pid=901179) Using native 16bit precision.
# (pid=901179) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901179)
# (pid=901179)   | Name   | Type | Params
# (pid=901179) --------------------------------
# (pid=901179) 0 | model1 | MLP  | 365 K
# (pid=901179) 1 | model2 | MLP  | 365 K
# (pid=901179) 2 | model3 | MLP  | 442 K
# (pid=901179) 3 | model4 | MLP  | 442 K
# (pid=901179) --------------------------------
# (pid=901179) 1.6 M     Trainable params
# (pid=901179) 0         Non-trainable params
# (pid=901179) 1.6 M     Total params
# (pid=901179) 6.460     Total estimated model params size (MB)
# (pid=901179) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901179)   warnings.warn(*args, **kwargs)
# (pid=901179) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901179)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:19:27,291	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_similarity_loss at 0x7f62addae310>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901175) GPU available: True, used: True
# (pid=901175) TPU available: None, using: 0 TPU cores
# (pid=901175) Using native 16bit precision.
# (pid=901175) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901175)
# (pid=901175)   | Name   | Type | Params
# (pid=901175) --------------------------------
# (pid=901175) 0 | model1 | MLP  | 200 K
# (pid=901175) 1 | model2 | MLP  | 200 K
# (pid=901175) 2 | model3 | MLP  | 239 K
# (pid=901175) 3 | model4 | MLP  | 239 K
# (pid=901175) --------------------------------
# (pid=901175) 879 K     Trainable params
# (pid=901175) 0         Non-trainable params
# (pid=901175) 879 K     Total params
# (pid=901175) 3.518     Total estimated model params size (MB)
# (pid=901175) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901175)   warnings.warn(*args, **kwargs)
# (pid=901175) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901175)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:25:10,614	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_mae_loss at 0x7f62addae3a0>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901171) GPU available: True, used: True
# (pid=901171) TPU available: None, using: 0 TPU cores
# (pid=901171) Using native 16bit precision.
# (pid=901171) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901171)
# (pid=901171)   | Name   | Type | Params
# (pid=901171) --------------------------------
# (pid=901171) 0 | model1 | MLP  | 44.0 K
# (pid=901171) 1 | model2 | MLP  | 44.0 K
# (pid=901171) 2 | model3 | MLP  | 63.3 K
# (pid=901171) 3 | model4 | MLP  | 63.3 K
# (pid=901171) --------------------------------
# (pid=901171) 214 K     Trainable params
# (pid=901171) 0         Non-trainable params
# (pid=901171) 214 K     Total params
# (pid=901171) 0.858     Total estimated model params size (MB)
# (pid=901171) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901171)   warnings.warn(*args, **kwargs)
# (pid=901171) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901171)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:28:38,432	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_similarity_loss at 0x7f62addae310>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901176) GPU available: True, used: True
# (pid=901176) TPU available: None, using: 0 TPU cores
# (pid=901176) Using native 16bit precision.
# (pid=901176) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901176)
# (pid=901176)   | Name   | Type | Params
# (pid=901176) --------------------------------
# (pid=901176) 0 | model1 | MLP  | 299 K
# (pid=901176) 1 | model2 | MLP  | 299 K
# (pid=901176) 2 | model3 | MLP  | 376 K
# (pid=901176) 3 | model4 | MLP  | 376 K
# (pid=901176) --------------------------------
# (pid=901176) 1.4 M     Trainable params
# (pid=901176) 0         Non-trainable params
# (pid=901176) 1.4 M     Total params
# (pid=901176) 5.403     Total estimated model params size (MB)
# (pid=901176) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901176)   warnings.warn(*args, **kwargs)
# (pid=901176) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901176)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:28:43,536	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_similarity_loss at 0x7f62addae310>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901170) GPU available: True, used: True
# (pid=901170) TPU available: None, using: 0 TPU cores
# (pid=901170) Using native 16bit precision.
# (pid=901170) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901170)
# (pid=901170)   | Name   | Type | Params
# (pid=901170) --------------------------------
# (pid=901170) 0 | model1 | MLP  | 203 K
# (pid=901170) 1 | model2 | MLP  | 203 K
# (pid=901170) 2 | model3 | MLP  | 242 K
# (pid=901170) 3 | model4 | MLP  | 242 K
# (pid=901170) --------------------------------
# (pid=901170) 891 K     Trainable params
# (pid=901170) 0         Non-trainable params
# (pid=901170) 891 K     Total params
# (pid=901170) 3.567     Total estimated model params size (MB)
# (pid=901170) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901170)   warnings.warn(*args, **kwargs)
# (pid=901170) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901170)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:28:52,169	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_similarity_loss at 0x7f62addae310>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901169) GPU available: True, used: True
# (pid=901169) TPU available: None, using: 0 TPU cores
# (pid=901169) Using native 16bit precision.
# (pid=901169) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901169)
# (pid=901169)   | Name   | Type | Params
# (pid=901169) --------------------------------
# (pid=901169) 0 | model1 | MLP  | 264 K
# (pid=901169) 1 | model2 | MLP  | 264 K
# (pid=901169) 2 | model3 | MLP  | 303 K
# (pid=901169) 3 | model4 | MLP  | 303 K
# (pid=901169) --------------------------------
# (pid=901169) 1.1 M     Trainable params
# (pid=901169) 0         Non-trainable params
# (pid=901169) 1.1 M     Total params
# (pid=901169) 4.544     Total estimated model params size (MB)
# (pid=901169) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901169)   warnings.warn(*args, **kwargs)
# (pid=901169) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901169)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:28:56,170	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_similarity_loss at 0x7f62addae310>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901174) GPU available: True, used: True
# (pid=901174) TPU available: None, using: 0 TPU cores
# (pid=901174) Using native 16bit precision.
# (pid=901174) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901174)
# (pid=901174)   | Name   | Type | Params
# (pid=901174) --------------------------------
# (pid=901174) 0 | model1 | MLP  | 144 K
# (pid=901174) 1 | model2 | MLP  | 144 K
# (pid=901174) 2 | model3 | MLP  | 183 K
# (pid=901174) 3 | model4 | MLP  | 183 K
# (pid=901174) --------------------------------
# (pid=901174) 656 K     Trainable params
# (pid=901174) 0         Non-trainable params
# (pid=901174) 656 K     Total params
# (pid=901174) 2.626     Total estimated model params size (MB)
# (pid=901174) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901174)   warnings.warn(*args, **kwargs)
# (pid=901174) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901174)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:30:19,149	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_similarity_loss at 0x7f62addae310>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901165) GPU available: True, used: True
# (pid=901165) TPU available: None, using: 0 TPU cores
# (pid=901165) Using native 16bit precision.
# (pid=901165) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901165)
# (pid=901165)   | Name   | Type | Params
# (pid=901165) --------------------------------
# (pid=901165) 0 | model1 | MLP  | 415 K
# (pid=901165) 1 | model2 | MLP  | 415 K
# (pid=901165) 2 | model3 | MLP  | 492 K
# (pid=901165) 3 | model4 | MLP  | 492 K
# (pid=901165) --------------------------------
# (pid=901165) 1.8 M     Trainable params
# (pid=901165) 0         Non-trainable params
# (pid=901165) 1.8 M     Total params
# (pid=901165) 7.269     Total estimated model params size (MB)
# (pid=901165) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901165)   warnings.warn(*args, **kwargs)
# (pid=901165) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901165)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:39:43,774	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_mae_loss at 0x7f62addae3a0>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901156) GPU available: True, used: True
# (pid=901156) TPU available: None, using: 0 TPU cores
# (pid=901156) Using native 16bit precision.
# (pid=901156) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901156)
# (pid=901156)   | Name   | Type | Params
# (pid=901156) --------------------------------
# (pid=901156) 0 | model1 | MLP  | 199 K
# (pid=901156) 1 | model2 | MLP  | 199 K
# (pid=901156) 2 | model3 | MLP  | 218 K
# (pid=901156) 3 | model4 | MLP  | 218 K
# (pid=901156) --------------------------------
# (pid=901156) 837 K     Trainable params
# (pid=901156) 0         Non-trainable params
# (pid=901156) 837 K     Total params
# (pid=901156) 3.349     Total estimated model params size (MB)
# (pid=901156) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901156)   warnings.warn(*args, **kwargs)
# (pid=901156) /home/nuoc/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:2610: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
# (pid=901156)   warnings.warn(
# (pid=901156) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901156)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:39:47,958	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_kl_loss at 0x7f62addae430>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901166) GPU available: True, used: True
# (pid=901166) TPU available: None, using: 0 TPU cores
# (pid=901166) Using native 16bit precision.
# (pid=901166) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901166)
# (pid=901166)   | Name   | Type | Params
# (pid=901166) --------------------------------
# (pid=901166) 0 | model1 | MLP  | 177 K
# (pid=901166) 1 | model2 | MLP  | 177 K
# (pid=901166) 2 | model3 | MLP  | 254 K
# (pid=901166) 3 | model4 | MLP  | 254 K
# (pid=901166) --------------------------------
# (pid=901166) 863 K     Trainable params
# (pid=901166) 0         Non-trainable params
# (pid=901166) 863 K     Total params
# (pid=901166) 3.455     Total estimated model params size (MB)
# (pid=901166) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901166)   warnings.warn(*args, **kwargs)
# (pid=901166) /home/nuoc/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:2610: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
# (pid=901166)   warnings.warn(
# (pid=901166) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901166)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:39:53,609	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_kl_loss at 0x7f62addae430>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901168) GPU available: True, used: True
# (pid=901168) TPU available: None, using: 0 TPU cores
# (pid=901168) Using native 16bit precision.
# (pid=901168) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901168)
# (pid=901168)   | Name   | Type | Params
# (pid=901168) --------------------------------
# (pid=901168) 0 | model1 | MLP  | 193 K
# (pid=901168) 1 | model2 | MLP  | 193 K
# (pid=901168) 2 | model3 | MLP  | 270 K
# (pid=901168) 3 | model4 | MLP  | 270 K
# (pid=901168) --------------------------------
# (pid=901168) 928 K     Trainable params
# (pid=901168) 0         Non-trainable params
# (pid=901168) 928 K     Total params
# (pid=901168) 3.713     Total estimated model params size (MB)
# (pid=901168) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901168)   warnings.warn(*args, **kwargs)
# (pid=901168) /home/nuoc/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:2610: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
# (pid=901168)   warnings.warn(
# (pid=901168) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901168)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:40:05,275	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_kl_loss at 0x7f62addae430>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901159) GPU available: True, used: True
# (pid=901159) TPU available: None, using: 0 TPU cores
# (pid=901159) Using native 16bit precision.
# (pid=901159) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901159)
# (pid=901159)   | Name   | Type | Params
# (pid=901159) --------------------------------
# (pid=901159) 0 | model1 | MLP  | 54.4 K
# (pid=901159) 1 | model2 | MLP  | 54.4 K
# (pid=901159) 2 | model3 | MLP  | 73.7 K
# (pid=901159) 3 | model4 | MLP  | 73.7 K
# (pid=901159) --------------------------------
# (pid=901159) 256 K     Trainable params
# (pid=901159) 0         Non-trainable params
# (pid=901159) 256 K     Total params
# (pid=901159) 1.025     Total estimated model params size (MB)
# (pid=901159) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901159)   warnings.warn(*args, **kwargs)
# (pid=901159) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901159)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:40:20,658	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_similarity_loss at 0x7f62addae310>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901167) GPU available: True, used: True
# (pid=901167) TPU available: None, using: 0 TPU cores
# (pid=901167) Using native 16bit precision.
# (pid=901167) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901167)
# (pid=901167)   | Name   | Type | Params
# (pid=901167) --------------------------------
# (pid=901167) 0 | model1 | MLP  | 198 K
# (pid=901167) 1 | model2 | MLP  | 198 K
# (pid=901167) 2 | model3 | MLP  | 217 K
# (pid=901167) 3 | model4 | MLP  | 217 K
# (pid=901167) --------------------------------
# (pid=901167) 832 K     Trainable params
# (pid=901167) 0         Non-trainable params
# (pid=901167) 832 K     Total params
# (pid=901167) 3.331     Total estimated model params size (MB)
# (pid=901167) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901167)   warnings.warn(*args, **kwargs)
# (pid=901167) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901167)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:40:24,545	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_mae_loss at 0x7f62addae3a0>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901167) FATAL: exception not rethrown
# (pid=901160) GPU available: True, used: True
# (pid=901160) TPU available: None, using: 0 TPU cores
# (pid=901160) Using native 16bit precision.
# (pid=901160) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901160)
# (pid=901160)   | Name   | Type | Params
# (pid=901160) --------------------------------
# (pid=901160) 0 | model1 | MLP  | 189 K
# (pid=901160) 1 | model2 | MLP  | 189 K
# (pid=901160) 2 | model3 | MLP  | 208 K
# (pid=901160) 3 | model4 | MLP  | 208 K
# (pid=901160) --------------------------------
# (pid=901160) 797 K     Trainable params
# (pid=901160) 0         Non-trainable params
# (pid=901160) 797 K     Total params
# (pid=901160) 3.188     Total estimated model params size (MB)
# (pid=901160) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901160)   warnings.warn(*args, **kwargs)
# (pid=901160) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901160)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:40:51,236	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_similarity_loss at 0x7f62addae310>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901158) GPU available: True, used: True
# (pid=901158) TPU available: None, using: 0 TPU cores
# (pid=901158) Using native 16bit precision.
# (pid=901158) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901158)
# (pid=901158)   | Name   | Type | Params
# (pid=901158) --------------------------------
# (pid=901158) 0 | model1 | MLP  | 83.4 K
# (pid=901158) 1 | model2 | MLP  | 83.4 K
# (pid=901158) 2 | model3 | MLP  | 121 K
# (pid=901158) 3 | model4 | MLP  | 121 K
# (pid=901158) --------------------------------
# (pid=901158) 410 K     Trainable params
# (pid=901158) 0         Non-trainable params
# (pid=901158) 410 K     Total params
# (pid=901158) 1.643     Total estimated model params size (MB)
# (pid=901158) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901158)   warnings.warn(*args, **kwargs)
# (pid=901158) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901158)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:40:55,697	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_similarity_loss at 0x7f62addae310>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901163) GPU available: True, used: True
# (pid=901163) TPU available: None, using: 0 TPU cores
# (pid=901163) Using native 16bit precision.
# (pid=901163) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901163)
# (pid=901163)   | Name   | Type | Params
# (pid=901163) --------------------------------
# (pid=901163) 0 | model1 | MLP  | 238 K
# (pid=901163) 1 | model2 | MLP  | 238 K
# (pid=901163) 2 | model3 | MLP  | 276 K
# (pid=901163) 3 | model4 | MLP  | 276 K
# (pid=901163) --------------------------------
# (pid=901163) 1.0 M     Trainable params
# (pid=901163) 0         Non-trainable params
# (pid=901163) 1.0 M     Total params
# (pid=901163) 4.123     Total estimated model params size (MB)
# (pid=901163) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901163)   warnings.warn(*args, **kwargs)
# (pid=901163) /home/nuoc/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:2610: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
# (pid=901163)   warnings.warn(
# (pid=901163) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901163)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:40:59,241	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_kl_loss at 0x7f62addae430>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901162) GPU available: True, used: True
# (pid=901162) TPU available: None, using: 0 TPU cores
# (pid=901162) Using native 16bit precision.
# (pid=901162) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901162)
# (pid=901162)   | Name   | Type | Params
# (pid=901162) --------------------------------
# (pid=901162) 0 | model1 | MLP  | 156 K
# (pid=901162) 1 | model2 | MLP  | 156 K
# (pid=901162) 2 | model3 | MLP  | 195 K
# (pid=901162) 3 | model4 | MLP  | 195 K
# (pid=901162) --------------------------------
# (pid=901162) 703 K     Trainable params
# (pid=901162) 0         Non-trainable params
# (pid=901162) 703 K     Total params
# (pid=901162) 2.815     Total estimated model params size (MB)
# (pid=901162) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901162)   warnings.warn(*args, **kwargs)
# (pid=901162) /home/nuoc/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:2610: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
# (pid=901162)   warnings.warn(
# (pid=901162) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901162)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:41:02,187	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_kl_loss at 0x7f62addae430>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901161) GPU available: True, used: True
# (pid=901161) TPU available: None, using: 0 TPU cores
# (pid=901161) Using native 16bit precision.
# (pid=901161) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901161)
# (pid=901161)   | Name   | Type | Params
# (pid=901161) --------------------------------
# (pid=901161) 0 | model1 | MLP  | 318 K
# (pid=901161) 1 | model2 | MLP  | 318 K
# (pid=901161) 2 | model3 | MLP  | 395 K
# (pid=901161) 3 | model4 | MLP  | 395 K
# (pid=901161) --------------------------------
# (pid=901161) 1.4 M     Trainable params
# (pid=901161) 0         Non-trainable params
# (pid=901161) 1.4 M     Total params
# (pid=901161) 5.710     Total estimated model params size (MB)
# (pid=901161) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901161)   warnings.warn(*args, **kwargs)
# (pid=901161) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901161)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:41:13,689	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_similarity_loss at 0x7f62addae310>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=901157) GPU available: True, used: True
# (pid=901157) TPU available: None, using: 0 TPU cores
# (pid=901157) Using native 16bit precision.
# (pid=901157) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=901157)
# (pid=901157)   | Name   | Type | Params
# (pid=901157) --------------------------------
# (pid=901157) 0 | model1 | MLP  | 198 K
# (pid=901157) 1 | model2 | MLP  | 198 K
# (pid=901157) 2 | model3 | MLP  | 237 K
# (pid=901157) 3 | model4 | MLP  | 237 K
# (pid=901157) --------------------------------
# (pid=901157) 871 K     Trainable params
# (pid=901157) 0         Non-trainable params
# (pid=901157) 871 K     Total params
# (pid=901157) 3.486     Total estimated model params size (MB)
# (pid=901157) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901157)   warnings.warn(*args, **kwargs)
# (pid=901157) /home/nuoc/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:2610: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
# (pid=901157)   warnings.warn(
# (pid=901157) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=901157)   warnings.warn(*args, **kwargs)
# 2021-04-01 00:41:25,159	INFO logger.py:688 -- Removed the following hyperparameter values when logging to tensorboard: {'loss_fn': <function mse_kl_loss at 0x7f62addae430>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# (pid=977379) GPU available: True, used: True
# (pid=977379) TPU available: None, using: 0 TPU cores
# (pid=977379) Using native 16bit precision.
# (pid=977379) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=977379)
# (pid=977379)   | Name   | Type | Params
# (pid=977379) --------------------------------
# (pid=977379) 0 | model1 | MLP  | 127 K
# (pid=977379) 1 | model2 | MLP  | 127 K
# (pid=977379) 2 | model3 | MLP  | 165 K
# (pid=977379) 3 | model4 | MLP  | 165 K
# (pid=977379) --------------------------------
# (pid=977379) 585 K     Trainable params
# (pid=977379) 0         Non-trainable params
# (pid=977379) 585 K     Total params
# (pid=977379) 2.342     Total estimated model params size (MB)
# (pid=977379) /home/nuoc/miniconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:52: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
# (pid=977379)   warnings.warn(*args, **kwargs)
# ...
# Epoch 12:  45%|████▍     | 360/805 [00:02<00:03, 122.96it/s, loss=0.0181, v_num=0.0, ptl/val_loss=0.00856]
# Epoch 12:  47%|████▋     | 380/805 [00:03<00:03, 122.99it/s, loss=0.0216, v_num=0.0, ptl/val_loss=0.00856]
# Epoch 12:  50%|████▉     | 400/805 [00:03<00:03, 123.13it/s, loss=0.0195, v_num=0.0, ptl/val_loss=0.00856]
# Epoch 12:  52%|█████▏    | 420/805 [00:03<00:03, 123.17it/s, loss=0.0181, v_num=0.0, ptl/val_loss=0.00856]
# Epoch 12:  55%|█████▍    | 440/805 [00:03<00:02, 123.34it/s, loss=0.017, v_num=0.0, ptl/val_loss=0.00856]
# Epoch 12:  57%|█████▋    | 460/805 [00:03<00:02, 122.88it/s, loss=0.0174, v_num=0.0, ptl/val_loss=0.00856]
# Epoch 12:  60%|█████▉    | 480/805 [00:03<00:02, 122.77it/s, loss=0.0171, v_num=0.0, ptl/val_loss=0.00856]
# Epoch 12:  62%|██████▏   | 500/805 [00:04<00:02, 122.73it/s, loss=0.0195, v_num=0.0, ptl/val_loss=0.00856]
# Epoch 12:  65%|██████▍   | 520/805 [00:04<00:02, 122.50it/s, loss=0.0187, v_num=0.0, ptl/val_loss=0.00856]
# Epoch 12:  67%|██████▋   | 540/805 [00:04<00:02, 121.92it/s, loss=0.0194, v_num=0.0, ptl/val_loss=0.00856]
# Epoch 12:  70%|██████▉   | 560/805 [00:04<00:02, 121.91it/s, loss=0.0187, v_num=0.0, ptl/val_loss=0.00856]
# Epoch 12:  72%|███████▏  | 580/805 [00:04<00:01, 121.58it/s, loss=0.0205, v_num=0.0, ptl/val_loss=0.00856]
# Epoch 12:  75%|███████▍  | 600/805 [00:04<00:01, 121.63it/s, loss=0.0175, v_num=0.0, ptl/val_loss=0.00856]
# Epoch 12:  77%|███████▋  | 620/805 [00:05<00:01, 121.77it/s, loss=0.0171, v_num=0.0, ptl/val_loss=0.00856]
# Epoch 12:  80%|███████▉  | 640/805 [00:05<00:01, 121.93it/s, loss=0.0193, v_num=0.0, ptl/val_loss=0.00856]
# Epoch 12:  82%|████████▏ | 660/805 [00:05<00:01, 124.30it/s, loss=0.0193, v_num=0.0, ptl/val_loss=0.00856]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/161 [00:00<?, ?it/s]
# (pid=978816)
# Epoch 12:  89%|████████▉ | 720/805 [00:05<00:00, 132.68it/s, loss=0.0193, v_num=0.0, ptl/val_loss=0.00856]
# (pid=978816)
# Epoch 12:  97%|█████████▋| 780/805 [00:05<00:00, 140.80it/s, loss=0.0193, v_num=0.0, ptl/val_loss=0.00856]
# Epoch 12: 100%|██████████| 805/805 [00:05<00:00, 143.12it/s, loss=0.0194, v_num=0.0, ptl/val_loss=0.00784]
# Epoch 12: 100%|██████████| 805/805 [00:05<00:00, 142.83it/s, loss=0.0194, v_num=0.0, ptl/val_loss=0.00784]
# ----------------------------------------------------------------------
# Done
# Best hyperparameters found were:  {'k': 250, 'hidden_dim': 256, 'lr': 1.3667400344322466e-05, 'batch_size': 5, 'loss_fn': <function mse_mae_loss at 0x7f62addae3a0>, 'ae_loss_fn': <function mse_loss at 0x7f62addae040>}
# Best achieved loss was:  {'loss': 0.0026309278327971697, 'time_this_iter_s': 5.882404565811157, 'done': True, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 88, 'experiment_id': '685a4ea48c5b49349b68efea7cd72075', 'date': '2021-04-01_00-39-43', 'timestamp': 1617230383, 'time_total_s': 563.850405216217, 'pid': 901165, 'hostname': 'Desktop', 'node_ip': '192.168.1.35', 'config': {'k': 250, 'hidden_dim': 256, 'lr': 1.3667400344322466e-05, 'batch_size': 5, 'loss_fn': <function mse_mae_loss at 0x7f60ac0601f0>, 'ae_loss_fn': <function mse_loss at 0x7f60ac060d30>}, 'time_since_restore': 563.850405216217, 'timesteps_since_restore': 0, 'iterations_since_restore': 88, 'trial_id': '3824a_00012', 'experiment_tag': '12_ae_loss_fn=<function mse_loss at 0x7f62addae040>,batch_size=5,hidden_dim=256,k=250,loss_fn=<function mse_mae_loss at 0x7f62addae3a0>,lr=1.3667e-05'}
# ----------------------------------------------------------------------
# [[(tensor([[-0.2372, -0.0966,  0.2825,  ..., -0.3402,  0.7422, -0.5709],
#            [-0.2372, -0.0966,  0.3481,  ..., -0.3639,  1.0605, -0.4706],
#            [-0.2372, -0.0966,  0.4090,  ..., -0.3853,  1.1937, -0.2022],
#            ...,
#            [-0.2372, -0.0966,  4.5444,  ..., -0.2629,  1.3802,  0.1209],
#            [-0.2372, -0.0966,  4.6135,  ..., -0.0344,  1.5821,  0.3293],
#            [-0.2372, -0.0966,  4.6833,  ..., -0.0496,  1.7635,  1.0254]]),
#    tensor([[ 1.4901e-07,  1.0809e-01,  3.9950e-01,  ..., -7.9226e-02,
#              7.5287e-01, -2.5661e-01],
#            [ 1.4901e-07,  1.0809e-01,  4.4990e-01,  ..., -9.7429e-02,
#              9.9763e-01, -1.7947e-01],
#            [ 1.4901e-07,  1.0809e-01,  4.9677e-01,  ..., -1.1390e-01,
#              1.1000e+00,  2.6897e-02],
#            ...,
#            [ 1.4901e-07,  1.0809e-01,  3.6760e+00,  ..., -1.9796e-02,
#              1.2434e+00,  2.7530e-01],
#            [ 1.4901e-07,  1.0809e-01,  3.7290e+00,  ...,  1.5587e-01,
#              1.3986e+00,  4.3545e-01],
#            [ 1.4901e-07,  1.0809e-01,  3.7828e+00,  ...,  1.4417e-01,
#              1.5380e+00,  9.7062e-01]])),
#   (tensor([[-1.8075e-01, -4.8344e-02,  1.6699e-01,  ..., -2.8598e-01,
#              8.6205e-01, -1.1644e+00],
#            [-1.8075e-01, -4.8344e-02,  2.2261e-01,  ..., -3.1768e-01,
#              1.1608e+00, -1.0462e+00],
#            [-1.8075e-01, -4.8344e-02,  2.8002e-01,  ..., -3.1894e-01,
#              1.2126e+00, -2.6153e-01],
#            ...,
#            [-1.8075e-01, -4.8344e-02,  3.6455e+00,  ..., -9.0518e-02,
#              1.7037e+00, -5.4766e-01],
#            [-1.8075e-01, -4.8344e-02,  3.7105e+00,  ...,  8.0782e-01,
#              2.8264e+00, -1.8485e+00],
#            [-1.8075e-01, -4.8344e-02,  3.7763e+00,  ...,  3.5759e-05,
#              5.3009e+00, -1.5035e+00]]),
#    tensor([[ 1.4901e-07,  1.0809e-01,  2.8387e-01,  ..., -8.5903e-02,
#              8.5127e-01, -8.0303e-01],
#            [ 1.4901e-07,  1.0809e-01,  3.2928e-01,  ..., -1.1178e-01,
#              1.0952e+00, -7.0650e-01],
#            [ 1.4901e-07,  1.0809e-01,  3.7615e-01,  ..., -1.1281e-01,
#              1.1374e+00, -6.5941e-02],
#            ...,
#            [ 1.4901e-07,  1.0809e-01,  3.1235e+00,  ...,  7.3661e-02,
#              1.5384e+00, -2.9952e-01],
#            [ 1.4901e-07,  1.0809e-01,  3.1766e+00,  ...,  8.0701e-01,
#              2.4548e+00, -1.3614e+00],
#            [ 1.4901e-07,  1.0809e-01,  3.2303e+00,  ...,  1.4758e-01,
#              4.4749e+00, -1.0798e+00]])),
#   (tensor([[-0.2635, -0.1216,  0.3397,  ..., -0.3663,  0.6894, -0.2243],
#            [-0.2635, -0.1216,  0.4092,  ..., -0.3881,  0.9314, -0.1979],
#            [-0.2635, -0.1216,  0.4712,  ..., -0.3976,  1.0608, -0.1810],
#            ...,
#            [-0.2635, -0.1216,  4.9417,  ..., -0.3241,  1.1009,  0.4236],
#            [-0.2635, -0.1216,  5.0114,  ..., -0.2081,  1.0134,  1.1832],
#            [-0.2635, -0.1216,  5.0819,  ..., -0.1204,  0.7160,  2.1467]]),
#    tensor([[ 1.4901e-07,  1.0809e-01,  4.5950e-01,  ..., -7.8304e-02,
#              7.2582e-01,  2.9867e-02],
#            [ 1.4901e-07,  1.0809e-01,  5.1240e-01,  ..., -9.4902e-02,
#              9.1021e-01,  4.9968e-02],
#            [ 1.4901e-07,  1.0809e-01,  5.5963e-01,  ..., -1.0214e-01,
#              1.0088e+00,  6.2874e-02],
#            ...,
#            [ 1.4901e-07,  1.0809e-01,  3.9649e+00,  ..., -4.6172e-02,
#              1.0393e+00,  5.2338e-01],
#            [ 1.4901e-07,  1.0809e-01,  4.0179e+00,  ...,  4.2239e-02,
#              9.7262e-01,  1.1019e+00],
#            [ 1.4901e-07,  1.0809e-01,  4.0717e+00,  ...,  1.0905e-01,
#              7.4612e-01,  1.8359e+00]]))],
#  [(tensor([[-0.5898, -0.5693,  0.0867,  ..., -0.4744, -0.4744,  4.0685],
#            [-0.5898, -0.5693,  0.1575,  ..., -0.4744, -0.4744,  3.7759],
#            [-0.5898, -0.5693,  0.2234,  ..., -0.4744, -0.4744,  3.4771],
#            ...,
#            [-0.5898, -0.5693,  4.6921,  ..., -0.4744, -0.4744,  3.7656],
#            [-0.5898, -0.5693,  4.7667,  ..., -0.4744, -0.4744,  4.0000],
#            [-0.5898, -0.5693,  4.8422,  ..., -0.4744, -0.4744,  4.0561]]),
#    tensor([[-0.0821, -0.0675,  0.3991,  ...,  0.0000,  0.0000,  3.2320],
#            [-0.0821, -0.0675,  0.4496,  ...,  0.0000,  0.0000,  3.0238],
#            [-0.0821, -0.0675,  0.4964,  ...,  0.0000,  0.0000,  2.8113],
#            ...,
#            [-0.0821, -0.0675,  3.6756,  ...,  0.0000,  0.0000,  3.0165],
#            [-0.0821, -0.0675,  3.7287,  ...,  0.0000,  0.0000,  3.1833],
#            [-0.0821, -0.0675,  3.7824,  ...,  0.0000,  0.0000,  3.2232]])),
#   (tensor([[-0.4975, -0.4786, -0.0222,  ..., -0.3908, -0.3908,  3.4214],
#            [-0.4975, -0.4786,  0.0369,  ..., -0.3908, -0.3908,  3.1508],
#            [-0.4975, -0.4786,  0.0978,  ..., -0.3908, -0.3908,  3.2644],
#            ...,
#            [-0.4975, -0.4786,  3.6699,  ..., -0.3908, -0.3908,  3.5312],
#            [-0.4975, -0.4786,  3.7389,  ..., -0.3908, -0.3908,  3.7481],
#            [-0.4975, -0.4786,  3.8088,  ..., -0.3908, -0.3908,  3.7999]]),
#    tensor([[-0.0821, -0.0675,  0.2835,  ...,  0.0000,  0.0000,  2.9320],
#            [-0.0821, -0.0675,  0.3289,  ...,  0.0000,  0.0000,  2.7239],
#            [-0.0821, -0.0675,  0.3758,  ...,  0.0000,  0.0000,  2.8113],
#            ...,
#            [-0.0821, -0.0675,  3.1232,  ...,  0.0000,  0.0000,  3.0165],
#            [-0.0821, -0.0675,  3.1762,  ...,  0.0000,  0.0000,  3.1833],
#            [-0.0821, -0.0675,  3.2300,  ...,  0.0000,  0.0000,  3.2232]])),
#   (tensor([[-0.6281, -0.6072,  0.1469,  ..., -0.5106, -0.5106,  4.3318],
#            [-0.6281, -0.6072,  0.2226,  ..., -0.5106, -0.5106,  4.0338],
#            [-0.6281, -0.6072,  0.2902,  ..., -0.5106, -0.5106,  3.5461],
#            ...,
#            [-0.6281, -0.6072,  5.1660,  ..., -0.5106, -0.5106,  3.8086],
#            [-0.6281, -0.6072,  5.2420,  ..., -0.5106, -0.5106,  4.0474],
#            [-0.6281, -0.6072,  5.3189,  ..., -0.5106, -0.5106,  4.1044]]),
#    tensor([[-0.0821, -0.0675,  0.4591,  ...,  0.0000,  0.0000,  3.3819],
#            [-0.0821, -0.0675,  0.5121,  ...,  0.0000,  0.0000,  3.1738],
#            [-0.0821, -0.0675,  0.5593,  ...,  0.0000,  0.0000,  2.8332],
#            ...,
#            [-0.0821, -0.0675,  3.9645,  ...,  0.0000,  0.0000,  3.0165],
#            [-0.0821, -0.0675,  4.0176,  ...,  0.0000,  0.0000,  3.1833],
#            [-0.0821, -0.0675,  4.0713,  ...,  0.0000,  0.0000,  3.2231]]))],
#  [(tensor([[-0.2560, -0.1118,  0.2772,  ..., -0.3672,  0.8000, -0.5725],
#            [-0.2560, -0.1118,  0.3445,  ..., -0.3892,  1.0528, -0.5287],
#            [-0.2560, -0.1118,  0.4070,  ..., -0.3954,  1.1556, -0.2444],
#            ...,
#            [-0.2560, -0.1118,  4.6507,  ..., -0.2673,  1.3735,  0.0945],
#            [-0.2560, -0.1118,  4.7215,  ..., -0.0432,  1.6225,  0.3321],
#            [-0.2560, -0.1118,  4.7933,  ..., -0.5940,  1.7621,  1.0333]]),
#    tensor([[ 1.4901e-07,  1.0809e-01,  3.9950e-01,  ..., -8.3278e-02,
#              7.9113e-01, -2.3705e-01],
#            [ 1.4901e-07,  1.0809e-01,  4.4990e-01,  ..., -9.9741e-02,
#              9.8052e-01, -2.0428e-01],
#            [ 1.4901e-07,  1.0809e-01,  4.9677e-01,  ..., -1.0436e-01,
#              1.0576e+00,  8.7280e-03],
#            ...,
#            [ 1.4901e-07,  1.0809e-01,  3.6760e+00,  ..., -8.3999e-03,
#              1.2208e+00,  2.6259e-01],
#            [ 1.4901e-07,  1.0809e-01,  3.7290e+00,  ...,  1.5943e-01,
#              1.4073e+00,  4.4060e-01],
#            [ 1.4901e-07,  1.0809e-01,  3.7828e+00,  ..., -2.5316e-01,
#              1.5119e+00,  9.6590e-01]])),
#   (tensor([[-0.2035, -0.0634,  0.1644,  ..., -0.3331,  0.9004, -1.2396],
#            [-0.2035, -0.0634,  0.2233,  ..., -0.3594,  1.2013, -1.1283],
#            [-0.2035, -0.0634,  0.2840,  ..., -0.3593,  1.2782, -0.2834],
#            ...,
#            [-0.2035, -0.0634,  3.8447,  ..., -0.0919,  1.7748, -0.6017],
#            [-0.2035, -0.0634,  3.9135,  ..., -0.0712,  2.6803, -2.1295],
#            [-0.2035, -0.0634,  3.9831,  ...,  0.5104,  5.5053, -1.8795]]),
#    tensor([[ 1.4901e-07,  1.0809e-01,  2.8387e-01,  ..., -1.0004e-01,
#              8.5175e-01, -7.9944e-01],
#            [ 1.4901e-07,  1.0809e-01,  3.2928e-01,  ..., -1.2030e-01,
#              1.0839e+00, -7.1360e-01],
#            [ 1.4901e-07,  1.0809e-01,  3.7615e-01,  ..., -1.2021e-01,
#              1.1432e+00, -6.1666e-02],
#            ...,
#            [ 1.4901e-07,  1.0809e-01,  3.1235e+00,  ...,  8.6101e-02,
#              1.5264e+00, -3.0727e-01],
#            [ 1.4901e-07,  1.0809e-01,  3.1766e+00,  ...,  1.0210e-01,
#              2.2251e+00, -1.4860e+00],
#            [ 1.4901e-07,  1.0809e-01,  3.2303e+00,  ...,  5.5078e-01,
#              4.4047e+00, -1.2932e+00]])),
#   (tensor([[-0.2800, -0.1363,  0.3311,  ..., -0.3755,  0.6483, -0.2671],
#            [-0.2800, -0.1363,  0.4015,  ..., -0.4093,  0.9538, -0.1997],
#            [-0.2800, -0.1363,  0.4643,  ..., -0.4157,  1.0556, -0.1985],
#            ...,
#            [-0.2800, -0.1363,  4.9936,  ..., -0.3482,  1.0981,  0.4138],
#            [-0.2800, -0.1363,  5.0642,  ..., -0.2233,  1.0253,  1.1935],
#            [-0.2800, -0.1363,  5.1356,  ..., -0.1366,  0.7150,  2.1653]]),
#    tensor([[ 1.4901e-07,  1.0809e-01,  4.5950e-01,  ..., -7.1803e-02,
#              6.9794e-01,  9.6969e-03],
#            [ 1.4901e-07,  1.0809e-01,  5.1240e-01,  ..., -9.7209e-02,
#              9.2764e-01,  6.0359e-02],
#            [ 1.4901e-07,  1.0809e-01,  5.5963e-01,  ..., -1.0197e-01,
#              1.0041e+00,  6.1296e-02],
#            ...,
#            [ 1.4901e-07,  1.0809e-01,  3.9649e+00,  ..., -5.1283e-02,
#              1.0362e+00,  5.2166e-01],
#            [ 1.4901e-07,  1.0809e-01,  4.0179e+00,  ...,  4.2639e-02,
#              9.8141e-01,  1.1078e+00],
#            [ 1.4901e-07,  1.0809e-01,  4.0717e+00,  ...,  1.0786e-01,
#              7.4811e-01,  1.8385e+00]]))],
#  [(tensor([[-0.6250, -0.6038,  0.0779,  ..., -0.5051, -0.5051,  4.2160],
#            [-0.6250, -0.6038,  0.1516,  ..., -0.5051, -0.5051,  3.9120],
#            [-0.6250, -0.6038,  0.2200,  ..., -0.5051, -0.5051,  3.6015],
#            ...,
#            [-0.6250, -0.6038,  4.8641,  ..., -0.5051, -0.5051,  3.9013],
#            [-0.6250, -0.6038,  4.9416,  ..., -0.5051, -0.5051,  4.1449],
#            [-0.6250, -0.6038,  5.0201,  ..., -0.5051, -0.5051,  4.2032]]),
#    tensor([[-0.0821, -0.0675,  0.3991,  ...,  0.0000,  0.0000,  3.2320],
#            [-0.0821, -0.0675,  0.4496,  ...,  0.0000,  0.0000,  3.0238],
#            [-0.0821, -0.0675,  0.4964,  ...,  0.0000,  0.0000,  2.8113],
#            ...,
#            [-0.0821, -0.0675,  3.6756,  ...,  0.0000,  0.0000,  3.0165],
#            [-0.0821, -0.0675,  3.7287,  ...,  0.0000,  0.0000,  3.1833],
#            [-0.0821, -0.0675,  3.7824,  ...,  0.0000,  0.0000,  3.2232]])),
#   (tensor([[-0.5464, -0.5261, -0.0363,  ..., -0.4319, -0.4319,  3.6593],
#            [-0.5464, -0.5261,  0.0271,  ..., -0.4319, -0.4319,  3.3689],
#            [-0.5464, -0.5261,  0.0925,  ..., -0.4319, -0.4319,  3.4907],
#            ...,
#            [-0.5464, -0.5261,  3.9260,  ..., -0.4319, -0.4319,  3.7771],
#            [-0.5464, -0.5261,  4.0000,  ..., -0.4319, -0.4319,  4.0098],
#            [-0.5464, -0.5261,  4.0750,  ..., -0.4319, -0.4319,  4.0655]]),
#    tensor([[-0.0821, -0.0675,  0.2835,  ...,  0.0000,  0.0000,  2.9320],
#            [-0.0821, -0.0675,  0.3289,  ...,  0.0000,  0.0000,  2.7239],
#            [-0.0821, -0.0675,  0.3758,  ...,  0.0000,  0.0000,  2.8113],
#            ...,
#            [-0.0821, -0.0675,  3.1232,  ...,  0.0000,  0.0000,  3.0165],
#            [-0.0821, -0.0675,  3.1762,  ...,  0.0000,  0.0000,  3.1833],
#            [-0.0821, -0.0675,  3.2300,  ...,  0.0000,  0.0000,  3.2232]])),
#   (tensor([[-0.6546, -0.6333,  0.1381,  ..., -0.5344, -0.5344,  4.4187],
#            [-0.6546, -0.6333,  0.2155,  ..., -0.5344, -0.5344,  4.1139],
#            [-0.6546, -0.6333,  0.2847,  ..., -0.5344, -0.5344,  3.6150],
#            ...,
#            [-0.6546, -0.6333,  5.2719,  ..., -0.5344, -0.5344,  3.8835],
#            [-0.6546, -0.6333,  5.3496,  ..., -0.5344, -0.5344,  4.1277],
#            [-0.6546, -0.6333,  5.4283,  ..., -0.5344, -0.5344,  4.1861]]),
#    tensor([[-0.0821, -0.0675,  0.4591,  ...,  0.0000,  0.0000,  3.3819],
#            [-0.0821, -0.0675,  0.5121,  ...,  0.0000,  0.0000,  3.1738],
#            [-0.0821, -0.0675,  0.5593,  ...,  0.0000,  0.0000,  2.8332],
#            ...,
#            [-0.0821, -0.0675,  3.9645,  ...,  0.0000,  0.0000,  3.0165],
#            [-0.0821, -0.0675,  4.0176,  ...,  0.0000,  0.0000,  3.1833],
#            [-0.0821, -0.0675,  4.0713,  ...,  0.0000,  0.0000,  3.2232]]))]]

# %%
clean_checkpoints(path=MODEL_PATH+"/MIX4")
# Out:
# Num checkpoints in /home/nuoc/Documents/MEX/models/MIX4: 666
